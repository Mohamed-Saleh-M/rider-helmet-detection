# %%
# %run Helmet_detect.py
# Out:
# 		RIDERS HELMET SURVEILLANCE
#
# LOCATION : 143502 - Abdal State Highway
# DATE : 15/01/23
#
# CASES LOG
# --------------
# SURVEILLANCE STREAMING STARTED AT 23:40:13
# --Case ACN15012323403538 issued
# --Case ACN15012323403784 issued
# --Case ACN15012323404133 issued
# --Case ACN15012323405458 issued
# --Case ACN15012323405668 issued
# --Case ACN15012323405917 issued
# --Case ACN15012323410221 issued
# --Case ACN15012323415582 issued
# --Case ACN15012323421150 issued
# --Case ACN15012323423737 issued
# --Case ACN15012323425213 issued
# --Case ACN15012323425453 issued
# --Case ACN15012323431068 issued
# --Case ACN15012323432824 issued
# --Case ACN15012323433020 issued
# --Case ACN15012323435548 issued
# --Case ACN15012323435811 issued
# --Case ACN15012323440094 issued
# --Case ACN15012323443281 issued
# --Case ACN15012323443498 issued
# --Case ACN15012323443688 issued
# --Case ACN15012323444986 issued
# --Case ACN15012323445181 issued
# --Case ACN15012323445343 issued
# ...
